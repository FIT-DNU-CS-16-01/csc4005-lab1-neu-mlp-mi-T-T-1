# %% [markdown]
# # CSC4005 Lab 1 Demo\n
# Notebook này chỉ là điểm bắt đầu. Sinh viên nên ưu tiên chạy `src/train.py` để làm thí nghiệm có cấu hình rõ ràng.

# %%
# !python -m src.train --help
# Out:
# d:\anaconda3\envs\csc4005-dl\python.exe: Error while finding module specification for 'src.train' (ModuleNotFoundError: No module named 'src')
